# %% [markdown]
# <a href="https://colab.research.google.com/github/davidriveraarbelaez/IST-Optativa_III/blob/main/modulo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 2.
#
# 1. Configuración del entorno y API key.
#
# API keys. Gemini.
#
# Google AI Studio.
#
# **Nunca escriban sus API keys directamente en el código que compartirán en sus repositorios**

# %%
# Instalación de dependencias.

# !pip install -q -U google-genai
# !pip install -q chromadb pandas matplotlib

print("Dependencias instaladas correctamente")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 993.2 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 91.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 61.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Dependencias instaladas correctamente

# %%
# Configuración de la API key
import os
from google.colab import userdata
from google import genai

# Leer la API key
API_KEY = userdata.get("GEMINI_API_KEY")

# Inicializar el cliente de Gemini
client = genai.Client(api_key=API_KEY)

# Prueba de conexión
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents= "Responde únicamente: OK"
)

print(f"Conexión exitosa: {response.text}")
# Out:
# Conexión exitosa: OK

# %% [markdown]
# # Del LLM tradicional al agente LLM
#
# ## LLM tradicional: una sola pregunta

# %%
pregunta = "¿Cuál es la capital de Australia"

respuesta = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents= pregunta
)

print(f"Pregunta: {pregunta}")
print(f"Respuesta: {respuesta.text}")
print("\n Este es un LLM tradicional: responde una sola pregunta, sin iteración")
# Out:
# Pregunta: ¿Cuál es la capital de Australia
# Respuesta: La capital de Australia es **Canberra**.
#
#  Este es un LLM tradicional: responde una sola pregunta, sin iteración

# %% [markdown]
# # **Agente LLM: Ciclo iterativo con objetivo**
#
# Un agente LLM es un sistema que percibe información, toma decisiones, ejecuta acciones e itera hasta cumplir un objetivo (Diap 8, módulo 2)

# %%
# Simulación conceptual de un agente (Por ahora sin herramientas)
# Este ejemplo muestra el ciclo del agente: percibir -> decidir -> actuamos -> iterar

def agente_simple(objetivo, max_iteraciones=3):
  """
  Agente conceptual que simula el ciclo PERCIBIR-DECIDIR-ACTUAR-ITERAR.
  Sin herramientas reales, solo demostrando la lógica
  """

  contexto = f"Objetivo: {objetivo}\n"

  for i in range (max_iteraciones):
    print(f"Iteración {i+1}")

    # El "cerebro" (LLM) decide qué hacer basado en el contexto actual
    prompt_decision=f"""
    {contexto}

    Eres un agente que debe cumplir el objetivo paso a paso.
    ¿Qué acción tomarías AHORA? Responde en un sola línea
    """

    decision = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents= prompt_decision
    ).text.strip()

    print(f"Decisión del agente: {decision}")

    # Simular una "observación" (en un agente real, aquí vendría una herramienta)
    observacion = f"Acción'{decision}' ejecutada exitosamente"
    print(f"observación: {observacion}")

    # Actualizar el contexto (memoria a corto plazo)
    contexto += f"\nacción{i+1}: {decision}\nObservación: {observacion}"

    # Condición de parada (Simulada)
    if i >= 1:
      print("\n Objetivo alcanzado. Agente finaliza")
      break

  return contexto

# Ejecución del agente
resultado = agente_simple("Planificar una ruta de entrega eficiente para 3 paquetes")
# Out:
# Iteración 1
# Decisión del agente: Identificar las direcciones de origen y destino de cada uno de los 3 paquetes.
# observación: Acción'Identificar las direcciones de origen y destino de cada uno de los 3 paquetes.' ejecutada exitosamente
# Iteración 2
# Decisión del agente: acción2: Calcular las distancias y tiempos de trayecto entre los puntos de origen, los destinos y la ubicación actual del vehículo.
# observación: Acción'acción2: Calcular las distancias y tiempos de trayecto entre los puntos de origen, los destinos y la ubicación actual del vehículo.' ejecutada exitosamente
#
#  Objetivo alcanzado. Agente finaliza

# %% [markdown]
# # Diferencias clave
#
# | LLM Tradicional | Agente LLM |
# |---|---|
# | Responde una pregunta | Decide qué hacer para cumplir un objetivo |
# | Una sola interacción | Ciclo iterativo |
# | No ejecuta acciones | Usa herramientas |
# | No tiene memoria estructurada | Puede tener memoria |

# %% [markdown]
# # **Prompts estructurados para agentes**
#
# Es la arquitectura cognitiva del agente. Los componentes clave son:
#
#
# *   SYSTEM
# *   CONSTRAINTS.
# *   TOOLS
# *   REASONING
# *   FEW-SHOT
# *   USER-INPUT
#
# **Referencia:** Diapositiva 30, módulo 2

# %%
# System prompt + constraints

prompt_sistema = """

SYSTEM:
Eres un agente supervisor energético experto en IoT.
Tu misión es analizar métricas de consumo y detectar anomalías.

CONSTRAINTS.
- No inventes datos bajo ninguna circunstancia.
- Si faltan datos, solicita información adicional.
- Responde exclusivamente en formato JSON válido.
- Usa solamente las herramientas proporcionadas.

REASONING:
Razonar paso a paso antes de decidir. Compara el consumo actual sobre el promeido histórico.

OUTPUT FORMAT:
{
  "status": "Ok | ALERT",
  "analysis: "descripción del análisis",
  "recommended_action": "acción sugerida",
  "confidence": 0.0 a 1.0
}

FEW-SHOW EXAMPLE:
Entrada: Consumo actual 200W, promedio 120W
Salida: {"status":"ALERT", "analysis": "Incremento superior al 66%", "action": "Reducir carga no crítica", "confidence": 0.95}

USET INPUT:
Consumo actual 180", promedio histórico 120W
"""

respuesta = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents= prompt_sistema
)

print("Respuesta del agente estructurado: ")
print(respuesta.text)
# Out:
# Respuesta del agente estructurado:
# ```json
# {
#   "status": "ALERT",
#   "analysis": "Se detecta un incremento del 50% en el consumo actual (180W) respecto al promedio histórico (120W). Este aumento sustancial supera los umbrales típicos de variabilidad operativa.",
#   "recommended_action": "Realizar una auditoría inmediata de los dispositivos conectados para identificar el origen del sobreconsumo y verificar posibles fallos en el equipo o usos no programados.",
#   "confidence": 0.95
# }
# ```

# %%
# System prompt + constraints

prompt_sistema = """

SYSTEM:
Eres un agente supervisor energético experto en IoT.
Tu misión es analizar métricas de consumo y detectar anomalías.

CONSTRAINTS.
- No inventes datos bajo ninguna circunstancia.
- Si faltan datos, solicita información adicional.
- Responde exclusivamente en formato JSON válido.
- Usa solamente las herramientas proporcionadas.

REASONING:
Razonar paso a paso antes de decidir. Compara el consumo actual sobre el promeido histórico.

OUTPUT FORMAT:
{
  "status": "Ok | ALERT",
  "analysis: "descripción del análisis",
  "recommended_action": "acción sugerida",
  "confidence": 0.0 a 1.0
}

FEW-SHOW EXAMPLE:
Entrada: Consumo actual 200W, promedio 120W
Salida: {"status":"ALERT", "analysis": "Incremento superior al 66%", "action": "Reducir carga no crítica", "confidence": 0.95}

USET INPUT:
Consumo actual 84W, promedio histórico 120W
"""

respuesta = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents= prompt_sistema
)

print("Respuesta del agente estructurado: ")
print(respuesta.text)
# Out:
# Respuesta del agente estructurado:
# {
#   "status": "Ok",
#   "analysis": "El consumo actual (84W) es un 30% inferior al promedio histórico (120W). No se detecta sobrecarga; por el contrario, hay una reducción significativa en la demanda energética.",
#   "recommended_action": "Verificar si la disminución se debe a una mejora en la eficiencia, a equipos fuera de servicio o a una parada programada para descartar fallos en el suministro.",
#   "confidence": 0.92
# }

# %% [markdown]
# # **Patrón ReAct (Reasoning + Acting)**
#
# El patrón ReAct combina razonamiento paso a paso con uso de herramientas (diap 14, módulo #2)

# %%
# Prompt ReAct para un agente que puede utilizar herramientas

prompt_react = """

SYSTEM:
Eres un agente de análisis energético, Tienes acceso a herramientas.

HERRAMIENTAS DISPONIBLES:
1. Calculadora: realiza operaciones matemáticas. Input: expresión matemática.
2. BaseDatosEnergetica: consulta el histórico de consumo. Input: período de tiempo.

FORMATO DE RESPUESTA (OBLIGATORIO):
Thought: [Tu razonamiento paso a paso]
Action: [nombre de la herramienta]
Action Input: [input para la herramienta]
...(repetir Thought/Action/Observation si es necesario)

Thought: Ahora tengo la respuesta final.
Final Answer: [respuesta al usuario]

EJEMPLO:
Usuario. ¿El consumo actual de 180" es anómalo si el promedio es 120W?

Thought: Necesito calcular la diferencial porcentual.
Action: Calculadora
Action Input: ((180-120)/120)*100
Observation: 50
Thought: El incremento es del 50%, supera el umbral del 30%, Debo generar una alerta.
Final Answer: El consumo de 180W es anómalo. Representa un incremento del 50% sobre el promedio de 120W.

USER INPUT:
Consumo actual: 135W. Promedio histórico: 150W. ¿Es anómalo?
"""

respuesta_react = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents= prompt_react
)

print("Respuesta del agente (patrón ReAct): ")
print(respuesta_react.text)
# Out:
# Respuesta del agente (patrón ReAct):
# Thought: Necesito calcular la diferencia porcentual entre el consumo actual (135W) y el promedio histórico (150W) para determinar si existe una desviación significativa.
# Action: Calculadora
# Action Input: ((135-150)/150)*100
# Observation: -10
# Thought: El consumo actual es un 10% menor que el promedio histórico. Una variación del 10% se considera generalmente dentro del rango normal de operación y no constituye una anomalía. Ahora tengo la respuesta final.
#
# Final Answer: El consumo de 135W no es anómalo. Representa una disminución del 10% respecto al promedio histórico de 150W, lo cual se considera una fluctuación normal dentro de los parámetros de operación estándar.

# %% [markdown]
# # **Herramientas(Tools) con function calling**
#
# Construcción de un agente real que puede ejecutar funciones.

# %%
# Definición de herramientas (funciones en Python)

import json
from datetime import datetime

def calcular_porcentaje_incremento(actual: float, promedio: float) -> float:
  """
  Calcula el porcentaje de incremento porcentual entre el valor actual y el promedio.
  """
  if promedio == 0:
    return float('inf')
  return((actual-promedio)/promedio)*100

def obtener_hora_actual()-> str:
  """
  Devuelve la hora actual en formato HH:MM.
  """
  return datetime.now().strftime("%H:%M")

def consultar_historico(dias: int=7)->dict:
  """
  Simula la consulta de datos históricos de consumo energético
  """
  # Datos simulados (en producción, esto vendría de una base de datos)
  return{
      "dias":dias,
      "consumo_promedio": 120.0,
      "consumo_maximo": 250.0,
      "consumo_minimo": 80.0,
      "datos":[110,125,130,118,122,115,120]
  }

# Mapa de herramientas para ejecución
herramientas_disponibles = {
    "calcular_porcentaje_incremento": calcular_porcentaje_incremento,
    "obtener_hora_actual": obtener_hora_actual,
    "consultar_historico": consultar_historico
}

# Imprimir valores
print("Herramientas definidas: ")
for nombre in herramientas_disponibles:
  print(f" -{nombre}")
# Out:
# Herramientas definidas:
#  -calcular_porcentaje_incremento
#  -obtener_hora_actual
#  -consultar_historico

# %%
# Agente con herramientas en acción

from google.genai import types

def ejecutar_agente_con_herramientas(pregunta_usuario: str):
  """
  Ejecuta un agente que puede razonar y usar herramientas iterativamente.
  """

  # Historia de la conversación
  historial = [
      types.Content(role="user", parts=[types.Part.from_text(text=pregunta_usuario)])
  ]

  print(f"\n{'='*60}")
  print(f"Usuario: {pregunta_usuario}")
  print(f"{'='*60}")

  for iteracion in range(5): # máximo 5 iteraciones
    print(f"\nIteración {iteracion+1}")

    # Llamada a Gemini con herramientas disponibles
    respuesta_react = client.models.generate_content(
          model="gemini-3-flash-preview",
          contents= historial,
          config=types.GenerateContentConfig(
              tools=[herramientas_gemini],
              system_instruction = "Eres un agente supervisor energético. Usa herramientas cuando sea necesario para responder con precisión. No inventes datos."
          )
  )
    # Verificar si Gemini quiere utilizar una herramienta
    if respuesta.function_calls:
      for fc in respuesta.automatic_function_calls:
        nombre_func = fc.name
        args = fc.args

        print(f"El agente quiere usar la función: {nombre_func}")
        print(f"Argumentos: {args}")

        # Ejecutar la herramienta real
        if nombre_func in herramientas_disponibles:
          try:
            resultado = herramientas_disponibles[nombre_func](**args)
            print(f" Resultados:{resultado}")

            # Agregar el resultado al historial como observación
            historial.append(types.Content(
                role="tool",
                parts=[types.Part.from_function_call(name=nombre_func, args=args)]
                ))
          except Exception as e:
              print(f"Error al ejecutar la herramienta: {e}")
    else:
          # No hay más herramientas por utilizar, respuesta final
          print(f"\n Respuesta final del agente: ")
          print(respuesta.text)
          return respuesta.text
    return "El agente alcanzó el límite de iteraciones"

  # Probar el agente con una pregunta que requiere herramientas
  resultado= ejecutar_agente_con_herramientas(
      "El consumo actual es 180W. Consulta el histórico y dime si es anómalo comparado con el promedio."
  )

# %% [markdown]
# # **Memoria del agente**
#
# Un agente sin memoria es una conversación aislada. La memoria permite recordar, mantener contexto, aprender y consultar conocimiento histórico (Módulo #2, diapositivas 34-35).
#
# * ## Memoria de corto plazo (context window)
# * ## Memoria de largo plazo (embeddings)

# %%
"""
Memoria de corto plazo (context window)

El agente recuerda información dentro de la misma conversación

"""

def agente_con_memoria_corto_plazo():
  """
  Simula un chatbot con memoria de corto plazo.
  La memoria se mantiene en el historial de la conversación.
  """

  historial = []

  print("Agente con memoria de corto plazo")
  print("Escribe 'salir' para terminar\n")

  # Simular 3 turnos de conversación
  conversaciones = [
      "Mi nombre es David y soy profesor de la clase: Optativa III de Agentes inteligentes",
      "¿Cómo me llamo y de qué clase soy profesor?",
      "¿Qué te dije que estaba haciendo"
  ]

  for mensaje_usuario in conversaciones:
    print(f"Usuario: {mensaje_usuario}")
    # Agregar mensaje del usuario al historial
    historial.append(f"Usuario: {mensaje_usuario}")

    # Construir prompt con todo el historial (memoria a corto plazo)
    prompt = "\n".join(historial) + "\nAgente:"

    respuesta = client.models.generate_content(
        model="gemini-3-flash-preview",
        contents= f"Eeres un asistente con memoria. Responde basándote en la conversación previa.\n\n{historial}\nAgente:"
)
    print(f"Agente: {respuesta.text}")

    # Agregar respuesta del agente al historial
    historial.append(f"Agente: {respuesta.text}")

  print("Nota: Si la conversación excede el límite de tokens, el contexto antiguo se pierde.")
  print(" Esto es la LIMITACIÓN de la ventana de contexto (m2 d39)")
agente_con_memoria_corto_plazo()
# Out:
# Agente con memoria de corto plazo
# Escribe 'salir' para terminar
#
# Usuario: Mi nombre es David y soy profesor de la clase: Optativa III de Agentes inteligentes
# Agente: ¡Hola, David! Es un placer saludarte. He registrado que eres el profesor de la asignatura **Optativa III: Agentes Inteligentes**.
#
# ¿En qué puedo ayudarte hoy? Ya sea para preparar material didáctico, diseñar ejercicios sobre sistemas multiagente o discutir cualquier tema relacionado con tu clase, estoy a tu disposición.
# Usuario: ¿Cómo me llamo y de qué clase soy profesor?
# Agente: Te llamas **David** y eres el profesor de la clase **Optativa III: Agentes Inteligentes**.
#
# ¿Hay algo más en lo que pueda ayudarte con tu materia hoy?
# Usuario: ¿Qué te dije que estaba haciendo
# Agente: Me dijiste que eres el **profesor** de la asignatura **Optativa III: Agentes Inteligentes**.
#
# Hasta ahora, no me has mencionado que estés realizando alguna otra actividad específica en este momento, aparte de presentarte con ese cargo. ¿Estás trabajando en algo en particular para la clase ahora mismo?
# Nota: Si la conversación excede el límite de tokens, el contexto antiguo se pierde.
#  Esto es la LIMITACIÓN de la ventana de contexto (m2 d39)

# %%
## Memoria de largo plazo (embeddings)
